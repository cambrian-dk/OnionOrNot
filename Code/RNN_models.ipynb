# %% [markdown]
# # Using Recursive Neural Network (RNN) - LSTM (Long Short Term Memory) Model for Satire News Headline Classification
#
#
# This notebook is created to explore the RNN approach for CS4248 Natural Language Processing (NLP) project.

# %% [markdown]
# ## 1. Checking if GPU is enabled in Google Colab Notebook

# %%
# !nvidia-smi
# Out:
# Fri Apr 23 12:55:49 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   59C    P8    11W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Necessary Imports for RNN model training
# Reference taken from [online](https://jovian.ai/aakanksha-ns/lstm-multiclass-text-classification)

# %%
import os
import torch
import nltk
import numpy as np
import string
import pickle

from collections import Counter
from torchsummary import summary
from matplotlib import pyplot as plt

from tqdm import tqdm_notebook

from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from sklearn.metrics import mean_squared_error
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import f1_score

nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %% [markdown]
# ## Mounting with Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Dataset Preprocessing

# %%
DATA_DIR = 'drive/MyDrive/datasets/'
X = np.load(os.path.join(DATA_DIR, 'merged_dataset_X.npy'))
y = np.load(os.path.join(DATA_DIR, 'merged_dataset_y.npy'))

# %% [markdown]
# ### Tokenisation & Lemmatization
# We now have a dataset of raw text (news headlines) with labels:
# 1. 0: Not Onion (True News Headline)
# 1. 1: Onion (Satire News Headline)
# 1. 2: Fake (Not Onion)
#
# We then process the text data to a list of tokens, and lemmatise any changed form of text

# %%
#tokenization & lemmatization
def preprocess_text(text):
    lemmatizer = WordNetLemmatizer()
    tokenized = word_tokenize(text)
    return [lemmatizer.lemmatize(token) for token in tokenized]

# %%
#Checking if tokenisation and vlaidation is working
preprocess_text("Ravioli, Ravioli, what's in the pocketoli")
# Out:
# ['Ravioli', ',', 'Ravioli', ',', 'what', "'s", 'in', 'the', 'pocketoli']

# %% [markdown]
# ### Creating Vocabulary of the dataset

# %%
#count number of occurences of each word
counts = Counter()
for sentence in tqdm_notebook(X):
    counts.update(preprocess_text(sentence))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   This is separate from the ipykernel package so we can avoid doing imports until
# HBox(children=(FloatProgress(value=0.0, max=68898.0), HTML(value='')))

# %%
#deleting infrequent words
print("num_words before:",len(counts.keys()))
for word in list(counts):
    if counts[word] < 2:
        del counts[word]
print("num_words after:",len(counts.keys()))
# Out:
# num_words before: 57326
# num_words after: 34364

# %%
#creating vocabulary
vocab2index = {"":0, "UNK":1}
words = ["", "UNK"]
for word in tqdm_notebook(counts):
    vocab2index[word] = len(words)
    words.append(word)

with open('drive/MyDrive/vocab2index.pickle', 'wb') as handle:
    pickle.dump(vocab2index, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   after removing the cwd from sys.path.
# HBox(children=(FloatProgress(value=0.0, max=34364.0), HTML(value='')))

# %%
#Checking max length from the entire news dataset
max(map(lambda x: len(preprocess_text(x)), X))
# Out:
# 79

# %% [markdown]
# ### Encoding the entire dataset with customised vocabulary

# %%
def encode_sentence(text, vocab2index, N=79):
    tokenized = preprocess_text(text)
    encoded = np.zeros(N, dtype=int)
    enc1 = np.array([vocab2index.get(word, vocab2index["UNK"]) for word in tokenized])
    length = min(N, len(enc1))
    encoded[:length] = enc1[:length]
    return encoded, length

# %%
X_encoded = [encode_sentence(x, vocab2index) for x in X]

# %%
from torch.utils.data import Dataset

class NewsDataset(Dataset):
    def __init__(self, X, y):
        self.X = np.array(X, dtype=object)
        self.y = np.array(y).astype(np.int)

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return torch.from_numpy(self.X[idx][0].astype(np.int32)), self.y[idx], self.X[idx][1]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.25, random_state=42)
print(len(X_train))
print(len(X_test))
# Out:
# 51673
# 17225

# %% [markdown]
# ## Defining the Neural Network Model
# Now the dataset is prepared, we need to create the RNN model for training. LSTM layer is used.

# %%
class RNN_Model(torch.nn.Module) :
    def __init__(self, vocab_size, embedding_dim, hidden_dim) :
        super().__init__()
        self.hidden_dim = hidden_dim
        self.dropout = torch.nn.Dropout(0.3)
        self.embeddings = torch.nn.Embedding(vocab_size, embedding_dim, padding_idx=0)
        self.lstm = torch.nn.LSTM(embedding_dim, hidden_dim, batch_first=True)
        self.linear = torch.nn.Linear(hidden_dim, 5)
        
    def forward(self, x, s):
        x = self.embeddings(x)
        x = self.dropout(x)
        x_pack = pack_padded_sequence(x, s, batch_first=True, enforce_sorted=False)
        out_pack, (ht, ct) = self.lstm(x_pack)
        out = self.linear(ht[-1])
        return out

# %% [markdown]
# ## Training Method

# %%
import torch.nn.functional as F
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence

def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']

def train_model(model, epochs=10, lr=0.001):
    train_acc_list = []
    train_loss_list = []
    val_acc_list = []
    val_loss_list = []

    parameters = filter(lambda p: p.requires_grad, model.parameters())
    optimizer = torch.optim.Adam(parameters, lr=lr)
    for i in range(1, epochs + 1):
        model.train()
        sum_loss = 0.0
        total = 0
        count = 0
        correct = 0
        for x, y, l in train_dl:
            count += 1
            x = x.long().cuda()
            y = y.long().cuda()
            y_pred = model(x, l)
            optimizer.zero_grad()
            loss = F.cross_entropy(y_pred, y)
            loss.backward()
            optimizer.step()
            sum_loss += loss.item()*y.shape[0]

            _, predicted = torch.max(y_pred, 1)
            correct += (predicted == y).sum().item()
            total += y.shape[0]
            accuracy = 100 * correct / total
            print('[epoch: %5d/%5d, batch: %5d] loss: %.3f, lr: %.10f, acc %d %%'% (i, epochs, count, loss.clone().item(), get_lr(optimizer), accuracy))
        train_acc_list.append(accuracy)
        train_loss_list.append(sum_loss / total)
        
        val_loss, val_acc, val_rmse, val_maxf1 = validation_metrics(model, val_dl, i)
        val_acc_list.append(val_acc.cpu() * 100)
        val_loss_list.append(val_loss)
        print("train loss %.3f, val loss %.3f, val accuracy %.3f, val rmse %.3f and %.3f val max f1" % (sum_loss/total, val_loss, val_acc, val_rmse, val_maxf1))
    return train_acc_list, val_acc_list, train_loss_list, val_loss_list

def validation_metrics (model, valid_dl, epoch_num):
    model.eval()
    correct = 0
    total = 0
    sum_loss = 0.0
    sum_rmse = 0.0
    max_f1 = 0

    # Initialize the prediction and label lists(tensors)
    predlist=torch.zeros(0,dtype=torch.long, device='cpu')
    lbllist=torch.zeros(0,dtype=torch.long, device='cpu')

    for x, y, l in valid_dl:
        x = x.long().cuda()
        y = y.long().cuda()
        y_hat = model(x, l)
        loss = F.cross_entropy(y_hat, y)
        pred = torch.max(y_hat, 1)[1]
        correct += (pred == y).float().sum()
        total += y.shape[0]
        sum_loss += loss.item()*y.shape[0]
        mse = mean_squared_error(pred.cpu(), y.unsqueeze(-1).cpu())
        sum_rmse += np.sqrt(mse)*y.shape[0]

        # add validation metrics for confusion matrix
        # append batch prediction results
        predlist=torch.cat([predlist,pred.view(-1).cpu()])
        lbllist=torch.cat([lbllist,y.view(-1).cpu()])

        # investigate individual examples
    max_f1 = max(max_f1, f1_score(predlist.numpy(), lbllist.numpy(), average='macro'))

    # Confusion matrix for the final epoch
    if(epoch_num == NUM_EPOCH):
        print(predlist.numpy())
        conf_mat=ConfusionMatrixDisplay(confusion_matrix(lbllist.numpy(), predlist.numpy(), normalize='true'), display_labels=["real", "onion", "fake"])
        conf_mat.plot(cmap=plt.cm.Blues,)
    return sum_loss/total, correct/total, sum_rmse/total, max_f1

# %% [markdown]
# ## Execution!

# %%
train_dataset = NewsDataset(X_train, y_train)
val_dataset = NewsDataset(X_test, y_test)

# %%
hidden_dim_size = 79
vocab_size = len(words)
model = RNN_Model(vocab_size=vocab_size, embedding_dim=79, hidden_dim=hidden_dim_size)
model = model.cuda().float()

# %%
from torch.utils.data import DataLoader

train_dl = DataLoader(train_dataset, batch_size=128, shuffle=False, num_workers=2, persistent_workers=False)
val_dl = DataLoader(val_dataset, batch_size=128)

# %%
IMG_DIR = 'drive/MyDrive/images'
NUM_EPOCH = 30

# %%
train_acc_list, val_acc_list, train_loss_list, val_loss_list = train_model(model, epochs=NUM_EPOCH)
# Out:
# Streaming output truncated to the last 5000 lines.
# [epoch:    18/   30, batch:   267] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   268] loss: 0.003, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   269] loss: 0.020, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   270] loss: 0.016, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   271] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   272] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   273] loss: 0.071, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   274] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   275] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   276] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   277] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   278] loss: 0.004, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   279] loss: 0.003, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   280] loss: 0.018, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   281] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   282] loss: 0.003, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   283] loss: 0.004, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   284] loss: 0.003, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   285] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   286] loss: 0.008, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   287] loss: 0.009, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   288] loss: 0.025, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   289] loss: 0.018, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   290] loss: 0.002, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   291] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   292] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   293] loss: 0.009, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   294] loss: 0.002, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   295] loss: 0.002, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   296] loss: 0.007, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   297] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   298] loss: 0.005, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   299] loss: 0.002, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   300] loss: 0.004, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   301] loss: 0.003, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   302] loss: 0.006, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   303] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   304] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   305] loss: 0.023, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   306] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   307] loss: 0.002, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   308] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   309] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   310] loss: 0.020, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   311] loss: 0.010, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   312] loss: 0.006, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   313] loss: 0.021, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   314] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   315] loss: 0.023, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   316] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   317] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   318] loss: 0.005, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   319] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   320] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   321] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   322] loss: 0.011, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   323] loss: 0.009, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   324] loss: 0.027, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   325] loss: 0.003, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   326] loss: 0.015, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   327] loss: 0.002, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   328] loss: 0.085, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   329] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   330] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   331] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   332] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   333] loss: 0.005, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   334] loss: 0.018, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   335] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   336] loss: 0.023, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   337] loss: 0.021, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   338] loss: 0.008, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   339] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   340] loss: 0.002, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   341] loss: 0.020, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   342] loss: 0.002, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   343] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   344] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   345] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   346] loss: 0.054, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   347] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   348] loss: 0.014, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   349] loss: 0.002, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   350] loss: 0.003, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   351] loss: 0.002, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   352] loss: 0.007, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   353] loss: 0.012, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   354] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   355] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   356] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   357] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   358] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   359] loss: 0.009, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   360] loss: 0.005, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   361] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   362] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   363] loss: 0.002, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   364] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   365] loss: 0.003, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   366] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   367] loss: 0.003, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   368] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   369] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   370] loss: 0.002, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   371] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   372] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   373] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   374] loss: 0.003, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   375] loss: 0.002, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   376] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   377] loss: 0.002, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   378] loss: 0.020, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   379] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   380] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   381] loss: 0.003, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   382] loss: 0.004, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   383] loss: 0.004, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   384] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   385] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   386] loss: 0.008, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   387] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   388] loss: 0.002, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   389] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   390] loss: 0.013, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   391] loss: 0.015, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   392] loss: 0.008, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   393] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   394] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   395] loss: 0.017, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   396] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   397] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   398] loss: 0.040, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   399] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   400] loss: 0.003, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   401] loss: 0.004, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   402] loss: 0.006, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   403] loss: 0.005, lr: 0.0010000000, acc 99 %
# [epoch:    18/   30, batch:   404] loss: 0.000, lr: 0.0010000000, acc 99 %
# train loss 0.006, val loss 0.282, val accuracy 0.953, val rmse 0.276 and 0.699 val max f1
# [epoch:    19/   30, batch:     1] loss: 0.001, lr: 0.0010000000, acc 100 %
# [epoch:    19/   30, batch:     2] loss: 0.014, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:     3] loss: 0.003, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:     4] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:     5] loss: 0.003, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:     6] loss: 0.003, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:     7] loss: 0.002, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:     8] loss: 0.010, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:     9] loss: 0.008, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    10] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    11] loss: 0.013, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    12] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    13] loss: 0.005, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    14] loss: 0.027, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    15] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    16] loss: 0.003, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    17] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    18] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    19] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    20] loss: 0.010, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    21] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    22] loss: 0.004, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    23] loss: 0.013, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    24] loss: 0.004, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    25] loss: 0.002, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    26] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    27] loss: 0.002, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    28] loss: 0.017, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    29] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    30] loss: 0.004, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    31] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    32] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    33] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    34] loss: 0.002, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    35] loss: 0.002, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    36] loss: 0.006, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    37] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    38] loss: 0.010, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    39] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    40] loss: 0.013, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    41] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    42] loss: 0.005, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    43] loss: 0.009, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    44] loss: 0.032, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    45] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    46] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    47] loss: 0.006, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    48] loss: 0.006, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    49] loss: 0.002, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    50] loss: 0.002, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    51] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    52] loss: 0.003, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    53] loss: 0.008, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    54] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    55] loss: 0.005, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    56] loss: 0.005, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    57] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    58] loss: 0.004, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    59] loss: 0.007, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    60] loss: 0.022, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    61] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    62] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    63] loss: 0.041, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    64] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    65] loss: 0.009, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    66] loss: 0.018, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    67] loss: 0.006, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    68] loss: 0.002, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    69] loss: 0.006, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    70] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    71] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    72] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    73] loss: 0.003, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    74] loss: 0.005, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    75] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    76] loss: 0.002, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    77] loss: 0.002, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    78] loss: 0.005, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    79] loss: 0.034, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    80] loss: 0.005, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    81] loss: 0.002, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    82] loss: 0.005, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    83] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    84] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    85] loss: 0.003, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    86] loss: 0.004, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    87] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    88] loss: 0.006, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    89] loss: 0.046, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    90] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    91] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    92] loss: 0.005, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    93] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    94] loss: 0.005, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    95] loss: 0.005, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    96] loss: 0.002, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    97] loss: 0.007, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    98] loss: 0.005, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:    99] loss: 0.038, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:   100] loss: 0.004, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:   101] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:   102] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:   103] loss: 0.015, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:   104] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:   105] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:   106] loss: 0.008, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:   107] loss: 0.000, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:   108] loss: 0.001, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:   109] loss: 0.043, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:   110] loss: 0.013, lr: 0.0010000000, acc 99 %
# [epoch:    19/   30, batch:
())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-588bf02581a9> in <module>()
# ----> 1 print(predlist.numpy())
#
# NameError: name 'predlist' is not defined

# %%
def plot_train_val_loss_graph(train_loss_list, val_loss_list, feature_name, stop_words=True, save=True):
    x = np.arange(0, NUM_EPOCH)
    plt.plot(x, train_loss_list, label="train loss")

    plt.plot(x, val_loss_list, label="val loss")
    plt.xlabel("epochs")
    plt.ylabel("loss %")
    plt.title(f"Train & Val Loss num {feature_name} Stopwords:{stop_words}")
    plt.legend()

    if save:
        file_name = f'train_val_loss_{feature_name}_stop_{stop_words}.png'
        plt.savefig(os.path.join(IMG_DIR, file_name))
        
    plt.show()

# %%
def plot_train_val_acc_graph(train_acc_list, val_acc_list, feature_name, stop_words=True, save=True):
    x = np.arange(0, NUM_EPOCH)
    plt.plot(x, train_acc_list, label="train accuracy")

    plt.plot(x, val_acc_list, label="val accuracy")
    plt.xlabel("epochs")
    plt.ylabel("accuracy %")
    plt.title(f"Train & Val Accuracy num {feature_name} Stopwords:{stop_words}")
    plt.legend()

    if save:
        file_name = f'train_val_acc_{feature_name}_stop_{stop_words}.png'
        plt.savefig(os.path.join(IMG_DIR, file_name))
        
    plt.show()

# %%
val_acc_list
# Out:
# [tensor(89.9390),
#  tensor(92.4761),
#  tensor(93.6662),
#  tensor(94.3338),
#  tensor(94.6357),
#  tensor(94.6589),
#  tensor(94.8795),
#  tensor(94.9202),
#  tensor(95.0537),
#  tensor(95.1176)]

# %%
train_acc_list
# Out:
# [81.28422967507208,
#  90.52503241538135,
#  92.83958740541482,
#  94.1729723453254,
#  94.95674723743541,
#  95.62634257736148,
#  96.22626903798889,
#  96.60751262748437,
#  97.01584967004045,
#  97.37774079306408]

# %%
plot_train_val_acc_graph(train_acc_list, val_acc_list, 'RNN', stop_words=False, save=True)
plot_train_val_loss_graph(train_loss_list, val_loss_list, 'RNN', stop_words=False, save=True)

# %% [markdown]
# ## Saving model

# %%
torch.save(model.state_dict(), 'drive/MyDrive/RNN.pth')

# %% [markdown]
# #Load model

# %%
model = RNN_Model(vocab_size=34366, embedding_dim=79, hidden_dim=79)
model = model.cuda().float()
model.load_state_dict(torch.load('drive/MyDrive/RNN.pth'))
# Out:
# <All keys matched successfully>

# %%
hidden_dim_size
# Out:
# 79

# %% [markdown]
# ## Testing with Sample news headline from Onion.com

# %%
class_map = {
    0: 'not onion (true)',
    1: 'onion',
    2: 'fake'
}

# %%
def evaluate_text(text, model):
    encoded_headline = encode_sentence(text, vocab2index)
    encoded_input = np.array([encoded_headline[0]]).astype(np.int32)
    sample_tensor = torch.from_numpy(encoded_input).long().cuda()
    l = encoded_headline[1]

    model.eval()
    y_hat = model(sample_tensor, torch.tensor([l]))
    pred = torch.max(y_hat, 1)[1].cpu().item()
    return class_map[pred]

# %%
evaluate_text("Myanmar envoy to London says military seized embassy in 'coup'", model)
# Out:
# 'not onion (true)'

# %%
evaluate_text("17-Year-Old Asks Friend What It Means When Guy You Like Wants Blanket Pardon", model)
# Out:
# 'onion'

# %%
evaluate_text("BREAKING NEWS: CRAZY Hillary's alien baby and 7 other out-of-this-world tabloid tales", model)
# Out:
# 'fake'

# %%
evaluate_text("American Media Banned In Other Countries", model)
# Out:
# 'onion'
